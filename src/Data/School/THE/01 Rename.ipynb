# %%
import pandas as pd
df=pd.read_csv('./CWURlime_rank.csv')
import numpy as np

# %%
rank_columns=list(filter(lambda x: "_feature_rank" in x, df.columns))
print(len(rank_columns))
# Out:
# 0

# %%
rank_columns=list(filter(lambda x: "_rank" in x, df.columns))
print(len(rank_columns))
# Out:
# 526

# %%
temp_dict={}
for col in rank_columns:
    temp_dict[col]=col.replace("_rank","_feature_rank")

# %%
df.rename(columns=temp_dict,inplace=True)
df
# Out:
#          model  UNITID  1-qid  two_realRank2  two_realRank  \
# 0         MART  166027   2012              2             2
# 1         MART  243744   2012              2             2
# 2         MART  166683   2012              7             7
# 3         MART  144050   2012              9             9
# 4         MART  110635   2012             10            10
# ..         ...     ...    ...            ...           ...
# 815  RandomFor  172644   2015            301           301
# 816  RandomFor  232186   2015            351           351
# 817  RandomFor  213543   2015            351           351
# 818  RandomFor  231174   2015            351           351
# 819  RandomFor  236939   2015            351           351
#
#                                      State  SCH_DEG  PREDDEG  HIGHDEG  \
# 0                       Harvard University        3        3        4
# 1                      Stanford University        3        3        4
# 2    Massachusetts Institute of Technology        3        3        4
# 3                    University of Chicago        3        3        4
# 4        University of California-Berkeley        3        3        4
# ..                                     ...      ...      ...      ...
# 815                 Wayne State University        3        3        4
# 816                George Mason University        3        3        4
# 817                      Lehigh University        3        3        4
# 818                  University of Vermont        3        3        4
# 819            Washington State University        3        3        4
#
#      CONTROL  ...  UNKN_ORIG_YR8_RT_feature_rank  \
# 0          2  ...                          417.0
# 1          2  ...                          515.0
# 2          2  ...                          147.0
# 3          2  ...                          142.0
# 4          1  ...                          245.0
# ..       ...  ...                            ...
# 815        1  ...                          405.0
# 816        1  ...                          402.0
# 817        2  ...                          332.0
# 818        1  ...                          169.0
# 819        1  ...                          472.0
#
#      WDRAW_4YR_TRANS_YR6_RT_feature_rank  WDRAW_4YR_TRANS_YR8_RT_feature_rank  \
# 0                                  424.0                                518.0
# 1                                  392.0                                176.0
# 2                                  113.0                                493.0
# 3                                  332.0                                 97.0
# 4                                  110.0                                305.0
# ..                                   ...                                  ...
# 815                                278.0                                219.0
# 816                                436.0                                484.0
# 817                                415.0                                152.0
# 818                                 55.0                                444.0
# 819                                139.0                                303.0
#
#      WDRAW_DEBT_MDN_feature_rank  WDRAW_DEBT_N_feature_rank  \
# 0                           26.0                      358.0
# 1                          503.0                      264.0
# 2                          242.0                      444.0
# 3                           88.0                      270.0
# 4                          246.0                       89.0
# ..                           ...                        ...
# 815                        165.0                      111.0
# 816                        397.0                      137.0
# 817                        380.0                      422.0
# 818                        118.0                      477.0
# 819                        418.0                      422.0
#
#      WDRAW_ORIG_YR2_RT_feature_rank  WDRAW_ORIG_YR3_RT_feature_rank  \
# 0                             127.0                            42.0
# 1                             508.0                           467.0
# 2                              87.0                            14.0
# 3                             330.0                           415.0
# 4                             210.0                           303.0
# ..                              ...                             ...
# 815                           458.0                           459.0
# 816                           205.0                           226.0
# 817                           423.0                           241.0
# 818                            70.0                           302.0
# 819                           241.0                           285.0
#
#      WDRAW_ORIG_YR4_RT_feature_rank  WDRAW_ORIG_YR6_RT_feature_rank  \
# 0                             425.0                            56.0
# 1                             370.0                           398.0
# 2                             513.0                           292.0
# 3                             354.0                           298.0
# 4                             265.0                           344.0
# ..                              ...                             ...
# 815                           267.0                            48.0
# 816                           408.0                            55.0
# 817                           193.0                           149.0
# 818                           350.0                           223.0
# 819                           264.0                           203.0
#
#      WDRAW_ORIG_YR8_RT_feature_rank
# 0                             433.0
# 1                             368.0
# 2                             382.0
# 3                             373.0
# 4                              68.0
# ..                              ...
# 815                           366.0
# 816                           521.0
# 817                            53.0
# 818                           300.0
# 819                           152.0
#
# [820 rows x 1584 columns]

# %%
df.shape
# Out:
# (820, 1584)

# %%
df.to_csv("CWURlime_rank.csv",index=None)
