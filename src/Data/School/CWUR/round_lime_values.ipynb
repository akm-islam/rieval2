# %%
import os
import pandas as pd

# %%
lime_data=pd.read_csv('CWUR_lime.csv')

# %%
contribution_columns=list(filter(lambda x: "_contribution" in x, lime_data.columns))
print(len(contribution_columns))
# Out:
# 526

# %%
lime_data[contribution_columns]=lime_data[contribution_columns].apply(lambda x:round(x,3))

# %%
lime_data
# Out:
#          model  UNITID  1-qid  two_realRank2  two_realRank  \
# 0         MART  166027   2012              1             1
# 1         MART  243744   2012              3             3
# 2         MART  166683   2012              2             2
# 3         MART  144050   2012             11            11
# 4         MART  110635   2012             10            10
# ..         ...     ...    ...            ...           ...
# 987  RandomFor  199148   2015            897           897
# 988  RandomFor  176372   2015            901           901
# 989  RandomFor  200280   2015            913           913
# 990  RandomFor  228796   2015            929           929
# 991  RandomFor  445188   2015            936           936
#
#                                           State  SCH_DEG  PREDDEG  HIGHDEG  \
# 0                            Harvard University        3        3        4
# 1                           Stanford University        3        3        4
# 2         Massachusetts Institute of Technology        3        3        4
# 3                         University of Chicago        3        3        4
# 4             University of California-Berkeley        3        3        4
# ..                                          ...      ...      ...      ...
# 987  University of North Carolina at Greensboro        3        3        4
# 988          University of Southern Mississippi        3        3        4
# 989                  University of North Dakota        3        3        4
# 990          The University of Texas at El Paso        3        3        4
# 991             University of California-Merced        3        3        4
#
#      CONTROL  ...  WDRAW_4YR_TRANS_YR6_RT_contribution  \
# 0          2  ...                                1.242
# 1          2  ...                               -2.279
# 2          2  ...                               -0.894
# 3          2  ...                               -0.963
# 4          1  ...                                1.033
# ..       ...  ...                                  ...
# 987        1  ...                               -0.281
# 988        1  ...                               -0.073
# 989        1  ...                               -0.013
# 990        1  ...                                0.220
# 991        1  ...                                0.111
#
#      WDRAW_4YR_TRANS_YR8_RT_contribution  WDRAW_DEBT_MDN_contribution  \
# 0                                  6.990                       -0.505
# 1                                 -0.612                       -0.170
# 2                                 -2.409                       -1.542
# 3                                 -4.417                       -1.823
# 4                                 -4.106                       -3.714
# ..                                   ...                          ...
# 987                               -0.050                       -0.026
# 988                                0.054                       -0.157
# 989                               -0.006                       -0.147
# 990                                0.184                       -0.011
# 991                               -0.019                       -0.034
#
#      WDRAW_DEBT_N_contribution  WDRAW_ORIG_YR2_RT_contribution  \
# 0                        4.179                           2.516
# 1                       -2.305                          -0.470
# 2                       -2.255                           3.055
# 3                       -0.999                           2.279
# 4                        0.986                          -2.555
# ..                         ...                             ...
# 987                      0.124                           0.003
# 988                     -0.034                           0.022
# 989                     -0.044                          -0.162
# 990                      0.118                           0.061
# 991                      0.194                          -0.097
#
#      WDRAW_ORIG_YR3_RT_contribution  WDRAW_ORIG_YR4_RT_contribution  \
# 0                             1.102                           2.713
# 1                            -1.782                          -0.859
# 2                            -2.195                          -1.059
# 3                             1.359                           0.538
# 4                             3.570                           1.738
# ..                              ...                             ...
# 987                           0.007                          -0.041
# 988                          -0.126                          -0.040
# 989                           0.051                           0.178
# 990                          -0.246                          -0.029
# 991                           0.052                           0.083
#
#      WDRAW_ORIG_YR6_RT_contribution  WDRAW_ORIG_YR8_RT_contribution  predicted
# 0                             0.088                           1.037        1.0
# 1                             2.426                          -0.767        1.0
# 2                            -0.413                          -0.202        1.0
# 3                             2.368                           4.436        1.0
# 4                             2.397                           0.055       31.0
# ..                              ...                             ...        ...
# 987                           0.023                          -0.103      197.0
# 988                          -0.089                           0.063      196.0
# 989                           0.034                          -0.007      189.0
# 990                           0.070                           0.075      187.0
# 991                           0.073                           0.082      142.0
#
# [992 rows x 1059 columns]

# %%
lime_data.to_csv('CWUR_lime.csv',index=None)
