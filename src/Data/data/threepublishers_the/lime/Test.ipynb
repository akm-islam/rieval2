# %%
import pandas as pd

# %%
df=pd.read_csv('../../school/lime/school_rank.csv')

# %%
df
# Out:
#        1-qid  country_feature_rank  female_percent_feature_rank  \
# 0       2011                     3                            7
# 1       2011                     7                            8
# 2       2011                     4                            7
# 3       2011                     4                            8
# 4       2011                     2                            5
# ...      ...                   ...                          ...
# 20819   2016                     1                            9
# 20820   2016                     1                            9
# 20821   2016                     1                            9
# 20822   2016                     4                           10
# 20823   2016                     7                           10
#
#        income_feature_rank  international_feature_rank  \
# 0                        1                           2
# 1                        1                           2
# ...
